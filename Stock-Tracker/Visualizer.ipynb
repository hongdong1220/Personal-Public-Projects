# %%
from alpha_vantage.timeseries import TimeSeries
import matplotlib.pyplot as plt
import pandas as pd
from APIKey import my_api_key


ts = TimeSeries(key=my_api_key, output_format='pandas', indexing_type='date')
# Get json object with the daily data and another with  the call's metadata
data, meta_data = ts.get_daily(symbol='FB', outputsize='full')

#Graph the Stock
data['4. close'].plot()
plt.title('Daily FB stock')
plt.show()
print(data)
print(meta_data)
# Out:
#             1. open   2. high  3. low  4. close    5. volume
# date
# 2020-06-26   232.64  233.0900  215.40  216.0800   75500103.0
# 2020-06-25   234.62  237.3000  232.74  235.6800   18704339.0
# 2020-06-24   241.20  243.2200  232.68  234.0200   20834904.0
# 2020-06-23   241.28  245.1853  239.86  242.2400   24017915.0
# 2020-06-22   238.56  240.7000  236.91  239.2200   18917782.0
# ...             ...       ...     ...       ...          ...
# 2012-05-24    32.95   33.2100   31.77   33.0300   50237200.0
# 2012-05-23    31.37   32.5000   31.36   32.0000   73600000.0
# 2012-05-22    32.61   33.5900   30.94   31.0000  101786600.0
# 2012-05-21    36.53   36.6600   33.00   34.0300  168192700.0
# 2012-05-18    42.05   45.0000   38.00   38.2318  573576400.0
#
# [2040 rows x 5 columns]
# {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': 'FB', '3. Last Refreshed': '2020-06-26', '4. Output Size': 'Full size', '5. Time Zone': 'US/Eastern'}
